# %% [markdown]
# #####Loops

# %%
for someChar in "Hello World":
    print (someChar)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for (x, y) in [('a',1), ('b',2), ('c',3), ('d',4)]:
    print (x, y)
# Out:
# a 1
# b 2
# c 3
# d 4
