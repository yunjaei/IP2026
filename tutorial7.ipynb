# %% [markdown]
# #####List Comprehensions

# %%
li = [3, 6, 2, 7]
out = []
for elem in li:
    print(out)
    out.append(elem*2)  
print(out)
# Out:
# []
# [6]
# [6, 12]
# [6, 12, 4]
# [6, 12, 4, 14]

# %%
[elem*2 for elem in li]
# Out:
# [6, 12, 4, 14]
